# %%
# !pip install transformers yfinance langchain pandas numpy scikit-learn matplotlib seaborn requests pandas

# %%
import transformers
import yfinance as yf
import pandas as pd
import numpy as np
import langchain
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns

print("All libraries have been successfully imported.")
# Out:
# All libraries have been successfully imported.

# %%
# Example: Fetch historical data for Apple stock
data = yf.download("AAPL", start="2020-01-01", end="2023-01-01")
data.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                      Adj Close      Close       High        Low  \
# Ticker                          AAPL       AAPL       AAPL       AAPL
# Date
# 2020-01-02 00:00:00+00:00  72.876122  75.087502  75.150002  73.797501
# 2020-01-03 00:00:00+00:00  72.167610  74.357498  75.144997  74.125000
# 2020-01-06 00:00:00+00:00  72.742638  74.949997  74.989998  73.187500
# 2020-01-07 00:00:00+00:00  72.400543  74.597504  75.224998  74.370003
# 2020-01-08 00:00:00+00:00  73.565201  75.797501  76.110001  74.290001
#
# Price                           Open     Volume
# Ticker                          AAPL       AAPL
# Date
# 2020-01-02 00:00:00+00:00  74.059998  135480400
# 2020-01-03 00:00:00+00:00  74.287498  146322800
# 2020-01-06 00:00:00+00:00  73.447502  118387200
# 2020-01-07 00:00:00+00:00  74.959999  108872000
# 2020-01-08 00:00:00+00:00  74.290001  132079200
